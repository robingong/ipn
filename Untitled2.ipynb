# %%
# 单坐标

import pandas as pd
import matplotlib.pyplot as plt
df2 = pd.read_excel("./yinong/cards_balance_20160529.xlsx",index_col="date",encoding='utf-8') 

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
#ax2 = fig.add_subplot(2,2,2) 会重叠


#Variable 
#ax.hist(df['cards'],bins = 5) #5个柱子，纵轴 加起来是150 天
ax.plot(df2['cards'])

ax2 = ax.twinx() # this is the important function
ax2.plot(df2['money'], 'r');

#Labels and Tit
plt.title('cards distribution')
plt.xlabel('days')
plt.ylabel('y')
plt.show()

# %%
# 双坐标

# 在双y轴制图中，绘图命令和以往不同，因而在此记录以备日后查阅。以一段程序为例
fig, ax1 = plt.subplots()  # 使用subplots()创建窗口
ax2 = ax1.twinx() # 创建第二个坐标轴
pos_z = df2.index.values
E_z=df2['money'].values
Enhance_z = df2['cards'].values

ax1.plot(pos_z, E_z, linewidth = 2)  # E_z是一组数据，不用在意
ax2.plot(pos_z, Enhance_z, linewidth = 3) # Ehance_z 是一组数据，不用在意
ax1.set_xlabel('position (nm)', fontsize = 16)  # fontsize使用方法和plt.xlabel()中一样
ax1.set_ylabel('|$E_{z}$| (V/m)', fontsize = 16)
ax2.set_ylabel('Enhancement', fontsize = 16)
ax1.set_xlim([0, max(pos_z)]) # 设置坐标轴范围的语句有所变化
ax1.set_ylim(0, max(E_z))
ax2.set_ylim([0, max(Enhance_z)])
plt.show()

# %%
x = df2.index.values
y1 = df2['money'].values
y2 = df2['cards'].values
# print x.size;print y1.size;print y2.size 都等于150
print x
'''
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, y1);
ax1.set_ylabel('Y values for exp(-x)');
ax2 = ax1.twinx() # this is the important function
ax2.plot(x, y2, 'r');
ax2.set_xlim([0, max(x)]);
ax2.set_ylabel('Y values for ln(x)');
ax2.set_xlabel('Same X for both exp(-x) and ln(x)');
plt.show()
'''
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2016-05-20', '2016-05-21', '2016-05-22', '2016-05-23',
#                '2016-05-24', '2016-05-25', '2016-05-26', '2016-05-27',
#                '2016-05-28', '2016-05-29'],
#               dtype='datetime64[ns]', name=u'date', length=150, freq=None)
# "\nfig = plt.figure()\nax1 = fig.add_subplot(111)\nax1.plot(x, y1);\nax1.set_ylabel('Y values for exp(-x)');\nax2 = ax1.twinx() # this is the important function\nax2.plot(x, y2, 'r');\nax2.set_xlim([0, max(x)]);\nax2.set_ylabel('Y values for ln(x)');\nax2.set_xlabel('Same X for both exp(-x) and ln(x)');\nplt.show()\n"

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0., np.e, 0.01)
y1 = np.exp(-x)
print y1
'''
y2 = np.log(x)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, y1);
ax1.set_ylabel('Y values for exp(-x)');
ax2 = ax1.twinx() # this is the important function
ax2.plot(x, y2, 'r');
ax2.set_xlim([0, np.e]);
ax2.set_ylabel('Y values for ln(x)');
ax2.set_xlabel('Same X for both exp(-x) and ln(x)');
plt.show()

'''
# Out:
# [ 1.          0.99004983  0.98019867  0.97044553  0.96078944  0.95122942
#   0.94176453  0.93239382  0.92311635  0.91393119  0.90483742  0.89583414
#   0.88692044  0.87809543  0.86935824  0.86070798  0.85214379  0.84366482
#   0.83527021  0.82695913  0.81873075  0.81058425  0.8025188   0.7945336
#   0.78662786  0.77880078  0.77105159  0.76337949  0.75578374  0.74826357
#   0.74081822  0.73344696  0.72614904  0.71892373  0.71177032  0.70468809
#   0.69767633  0.69073433  0.68386141  0.67705687  0.67032005  0.66365025
#   0.65704682  0.65050909  0.64403642  0.63762815  0.63128365  0.62500227
#   0.61878339  0.61262639  0.60653066  0.60049558  0.59452055  0.58860497
#   0.58274825  0.57694981  0.57120906  0.56552544  0.55989837  0.55432728
#   0.54881164  0.54335087  0.53794444  0.5325918   0.52729242  0.52204578
#   0.51685133  0.51170858  0.50661699  0.50157607  0.4965853   0.4916442
#   0.48675226  0.48190899  0.47711392  0.47236655  0.46766643  0.46301307
# ...

# %%
print df2['money'].values
# Out:
# [  1.19989387e+10   1.19989387e+10   1.19989387e+10   1.19989387e+10
#    1.19989387e+10   1.19989387e+10   1.19989387e+10   1.19989387e+10
#    1.19989387e+10   1.19989387e+10   1.21255672e+10   1.21255672e+10
#    1.21587611e+10   1.21587611e+10   1.21516015e+10   1.21516015e+10
#    1.21516015e+10   1.25014332e+10   1.25014332e+10   1.25014332e+10
#    1.25014332e+10   1.25088807e+10   1.25088807e+10   1.25088807e+10
#    1.25088807e+10   1.25088807e+10   1.24842438e+10   1.33123807e+10
#    1.33481747e+10   1.33481747e+10   1.35930082e+10   1.35930082e+10
#    1.35930082e+10   1.35930082e+10   1.35930082e+10   1.35930082e+10
#    1.35930082e+10   1.35930082e+10   1.35930082e+10   1.35930082e+10
#    1.37317251e+10   1.37317251e+10   1.38099647e+10   1.38099647e+10
#    1.38366137e+10   1.49089306e+10   1.49089306e+10   1.49089306e+10
#    1.49089306e+10   1.49093934e+10   1.49716448e+10   1.49716448e+10
#    1.49716448e+10   1.49984512e+10   1.50271765e+10   1.51218941e+10
# ...
